# %% [markdown]
# <a href="https://colab.research.google.com/github/Suryansh-Srivastava-271/Algo-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    return distances, previous


def shortest_path(graph, start, end):
    distances, previous = dijkstra(graph, start)
    path = []
    current = end

    while current is not None:
        path.insert(0, current)
        current = previous[current]

    return path, distances[end]


graph = {}
n = int(input("Enter number of nodes: "))
for i in range(n):
    node = input(f"Enter node {i+1} name: ")
    graph[node] = {}

edges = int(input("Enter number of edges: "))
for i in range(edges):
    u = input("From node: ")
    v = input("To node: ")
    w = int(input("Weight: "))
    graph[u][v] = w
    graph[v][u] = w

start = input("Enter source node: ")
end = input("Enter destination node: ")
path, distance = shortest_path(graph, start, end)
print(f"Shortest path from {start} to {end}: {' -> '.join(path)} with total distance {distance}")

graph["X"] = {}
graph["Y"] = {}
print("Added nodes X and Y.")

for src in graph.keys():
    print(f"\nTesting source: {src}")
    for dest in graph.keys():
        if src != dest:
            path, distance = shortest_path(graph, src, dest)
            print(f"{src} -> {dest}: {' -> '.join(path)} (distance {distance})")
# Out:
# Enter number of nodes: 5
# Enter node 1 name: A
# Enter node 2 name: B
# Enter node 3 name: C
# Enter node 4 name: D
# Enter node 5 name: E
# Enter number of edges: 6
# From node: A
# To node: B
# Weight: 9
# From node: B
# To node: C
# Weight: 8
# From node: C
# To node: D
# Weight: 1
# From node: D
# To node: E
# Weight: 5
# From node: B
# To node: E
# Weight: 13
# From node: C
# To node: E
# Weight: 2
# Enter source node: A
# Enter destination node: E
# Shortest path from A to E: A -> B -> C -> E with total distance 19
# Added nodes X and Y.
#
# Testing source: A
# A -> B: A -> B (distance 9)
# A -> C: A -> B -> C (distance 17)
# A -> D: A -> B -> C -> D (distance 18)
# A -> E: A -> B -> C -> E (distance 19)
# A -> X: X (distance inf)
# A -> Y: Y (distance inf)
#
# Testing source: B
# B -> A: B -> A (distance 9)
# B -> C: B -> C (distance 8)
# B -> D: B -> C -> D (distance 9)
# B -> E: B -> C -> E (distance 10)
# B -> X: X (distance inf)
# B -> Y: Y (distance inf)
#
# Testing source: C
# C -> A: C -> B -> A (distance 17)
# C -> B: C -> B (distance 8)
# C -> D: C -> D (distance 1)
# C -> E: C -> E (distance 2)
# C -> X: X (distance inf)
# C -> Y: Y (distance inf)
#
# Testing source: D
# D -> A: D -> C -> B -> A (distance 18)
# D -> B: D -> C -> B (distance 9)
# D -> C: D -> C (distance 1)
# D -> E: D -> C -> E (distance 3)
# D -> X: X (distance inf)
# D -> Y: Y (distance inf)
#
# Testing source: E
# E -> A: E -> C -> B -> A (distance 19)
# E -> B: E -> C -> B (distance 10)
# E -> C: E -> C (distance 2)
# E -> D: E -> C -> D (distance 3)
# E -> X: X (distance inf)
# E -> Y: Y (distance inf)
#
# Testing source: X
# X -> A: A (distance inf)
# X -> B: B (distance inf)
# X -> C: C (distance inf)
# X -> D: D (distance inf)
# X -> E: E (distance inf)
# X -> Y: Y (distance inf)
#
# Testing source: Y
# Y -> A: A (distance inf)
# Y -> B: B (distance inf)
# Y -> C: C (distance inf)
# Y -> D: D (distance inf)
# Y -> E: E (distance inf)
# Y -> X: X (distance inf)
