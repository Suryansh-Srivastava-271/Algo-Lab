# %% [markdown]
# <a href="https://colab.research.google.com/github/Suryansh-Srivastava-271/Algo-Lab/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )

def even_odd(n):
  if n%2==0:
    return True
  else :
    return False

time = []
checking = []
for i in range(5):
  n = int(input("Enter the number : "))
  check = even_odd(n)
  checking.append(check)
  time.append(1)
  if check:
    print("It's even")
  else :
    print("It's odd")

plt.figure()
plt.plot(checking,time)
plt.xlabel("Checking")
plt.ylabel("Values Entered")
plt.title("Checking Even Odd")
plt.show()
# Out:
# Enter the number : 1
# It's odd
# Enter the number : 2
# It's even
# Enter the number : 3
# It's odd
# Enter the number : 4
# It's even
# Enter the number : 5
# It's odd

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)

def adding(a,b):
  return a+b

time = []
n_values = list(range(1, 101))
for i in n_values:
  time.append(i)
  ans = adding(i,i+1)


plt.figure()
plt.plot(n_values,time)
plt.xlabel("this is sum")
plt.ylabel("time")
plt.title("Time Complexity")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.
import math
def lograthmic_time(num):
  count = 0;
  while(num > 1):
    count += 1
    num //= 2
  return count

in_values2 = list(range(1,101))
time_val2 = []
for n in in_values2:
  lograthmic_time(n)
  time_val2.append(math.log(n,2))

plt.figure()
plt.plot(in_values2,time_val2)
plt.xlabel("Input values")
plt.ylabel("Time values")
plt.title("Time Complexity O(log n)")
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
def log_linear(num):
  count = 0
  for i in range(1,num):
    while(i > 1):
      i //= 2
      count += 1

  return count

in_values3 = list(range(1,31))
time_val3 = []
for i in in_values3:
  time_val3.append(log_linear(i))

plt.figure()
plt.plot(in_values3,time_val3)
plt.xlabel("Input values")
plt.ylabel("Time values")
plt.title("Time Complexity O(n log n)")
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
def Quadratic(n):
  count = 0;
  for i in range(n):
    for j in range(n):
      count += 1

  return count

in_values4 = list(range(1,21))
time_val4 = []
for i in in_values4:
  time_val4.append(Quadratic(i))

plt.figure()
plt.plot(in_values4,time_val4)
plt.xlabel("Input values")
plt.ylabel("Time values")
plt.title("Time Complexity O(n^c)")
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
def exponential(n):
    if n <= 1:
        return 1
    return exponential(n-1) + exponential(n-1)

in_values5 = list(range(1, 15))
time_val5 = []

for n in in_values5:
    time_val5.append(2**n)

plt.plot(in_values5, time_val5)
plt.xlabel("Input size n")
plt.ylabel("Time values")
plt.title("Exponential Time Complexity O(c^n)")
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
def constant(n):
  return 1

def linear(n):
  count = 0
  for i in range(n):
    count += 1
  return count

def log_linear(num):
  count = 0
  for i in range(1,num):
    while(i > 1):
      i //= 2
      count += 1

  return count

def Quadratic(n):
  count = 0;
  for i in range(n):
    for j in range(n):
      count += 1

  return count

def exponential(n, base=2):
  return base**n

inp1 = list(range(1,21))
inp2 = list(range(1,21))
inp3 = list(range(1,21))
inp4 = list(range(1,21))
inp5 = list(range(1,10))

t1 = []
t2 = []
t3 = []
t4 = []
t5 = []

for n in inp1:
  t1.append(constant(n))

for n in inp2:
  t2.append(linear(n))

for n in inp3:
 t3.append(log_linear(n))

for n in inp4:
  t4.append(Quadratic(n))

for n in inp5:
  t5.append(exponential(n))

plt.figure()
plt.plot(inp1,t1, label='O(1) Constant')
plt.plot(inp2,t2, label='O(n) Linear')
plt.plot(inp3,t3, label='O(n log n) Log-Linear')
plt.plot(inp4,t4, label='O(n^c) Quadratic')
plt.plot(inp5,t5, label='O(c^n) Exponential')

plt.xlabel("Input Size n ")
plt.ylabel("Time values")
plt.title("Time Complexity Graph")
plt.legend()
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(n log n)
import random
def partition(arr, low, high, counter):
    pivot = arr[high]
    i = low - 1
    for j in range(low, high):
        counter[0] += 1
        if arr[j] < pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

def quick_sort(arr, low, high, counter):
    if low < high:
        pi = partition(arr, low, high, counter)
        quick_sort(arr, low, pi - 1, counter)
        quick_sort(arr, pi + 1, high, counter)


n_values = list(range(5, 55, 5))
operations = []

for n in n_values:
    arr = random.sample(range(1, 1000), n)
    counter = [0]
    quick_sort(arr, 0, n - 1, counter)
    operations.append(counter[0])

plt.plot(n_values,operations)
plt.xlabel("Input size n")
plt.ylabel("Time values")
plt.title("Quick Sort time Complexity O(n log n)")
plt.show()
